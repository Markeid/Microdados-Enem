# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
mediaEnemporMunicipio = pd.read_csv("C:/Users/BlueShift/Documents/mediaEnemporMunicipio.csv", sep=",", index_col=0)

# %%
mediaEnemporMunicipio.head()
# Out:
#    CO_MUNICIPIO_ESC       NO_MUNICIPIO_ESC  CO_UF_ESC SG_UF_ESC  NU_NOTA_CN  \
# 0         1100015.0  Alta Floresta D'Oeste       11.0        RO  488.157812
# 1         1100023.0              Ariquemes       11.0        RO  491.511969
# 2         1100031.0                 Cabixi       11.0        RO  493.366667
# 3         1100049.0                 Cacoal       11.0        RO  497.413115
# 4         1100056.0             Cerejeiras       11.0        RO  471.411429
#
#    NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO
# 0  495.502941  513.200000  506.317188       590.882353
# 1  503.362411  517.528369  515.933591       555.319149
# 2  487.233333  537.366667  469.800000       473.333333
# 3  510.974848  525.507273  535.113443       587.818182
# 4  493.240000  507.700000  496.380000       530.857143

# %%
#importando Atlas
atlasHumano = pd.read_csv("C:/Users/BlueShift/Desktop/brutos/atlas2013_dadosbrutos.csv", 
sep=",")

# %%
atlasHumano.head()
# Out:
#     ANO        UF  Codmun6  Codmun7              Município       LONG  \
# 0  1991  RONDÔNIA   110001  1100015  ALTA FLORESTA D'OESTE -61.999824
# 1  1991  RONDÔNIA   110002  1100023              ARIQUEMES -63.033269
# 2  1991  RONDÔNIA   110003  1100031                 CABIXI -60.544314
# 3  1991  RONDÔNIA   110004  1100049                 CACOAL -61.442944
# 4  1991  RONDÔNIA   110005  1100056             CEREJEIRAS -60.818426
#
#          LAT         Alt  ESPVIDA  FECTOT  ...  PIA1517  PIA18M    POP   POPT  \
# 0 -11.935540  337.735719    62.01    4.08  ...      NaN     NaN  23417  22835
# 1  -9.908463  138.688981    66.02    3.72  ...      NaN     NaN  56061  55018
# 2 -13.499763  236.063160    63.16    3.89  ...      NaN     NaN   7601   5846
# 3 -11.433865  177.453547    65.03    3.81  ...      NaN     NaN  69173  66534
# 4 -13.195033  262.811307    62.73    3.55  ...      NaN     NaN  19451  19030
#
#    I_ESCOLARIDADE  I_FREQ_PROP   IDHM  IDHM_E  IDHM_L  IDHM_R
# ...

# %%
MediaEnemIDHM = pd.merge(mediaEnemporMunicipio, atlasHumano, how="left", left_on=['CO_MUNICIPIO_ESC'], right_on=['Codmun7'])

# %%
MediaEnemIDHM.head()
# Out:
#    CO_MUNICIPIO_ESC       NO_MUNICIPIO_ESC  CO_UF_ESC SG_UF_ESC  NU_NOTA_CN  \
# 0         1100015.0  Alta Floresta D'Oeste       11.0        RO  488.157812
# 1         1100015.0  Alta Floresta D'Oeste       11.0        RO  488.157812
# 2         1100015.0  Alta Floresta D'Oeste       11.0        RO  488.157812
# 3         1100023.0              Ariquemes       11.0        RO  491.511969
# 4         1100023.0              Ariquemes       11.0        RO  491.511969
#
#    NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO     ANO  ... PIA1517  \
# 0  495.502941  513.200000  506.317188       590.882353  1991.0  ...     NaN
# 1  495.502941  513.200000  506.317188       590.882353  2000.0  ...  1830.0
# 2  495.502941  513.200000  506.317188       590.882353  2010.0  ...  1602.0
# 3  503.362411  517.528369  515.933591       555.319149  1991.0  ...     NaN
# 4  503.362411  517.528369  515.933591       555.319149  2000.0  ...  5190.0
#
# ...

# %%
MediaEnemIDHM = MediaEnemIDHM.filter(items=['CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',	
'CO_UF_ESC', 'SG_UF_ESC', 'NU_NOTA_LC',	'NU_NOTA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_REDACAO',
'IDHM',	'IDHM_E', 'IDHM_L',	'IDHM_R'])

# %%
MediaEnemIDHM
# Out:
#        CO_MUNICIPIO_ESC       NO_MUNICIPIO_ESC  CO_UF_ESC SG_UF_ESC  \
# 0             1100015.0  Alta Floresta D'Oeste       11.0        RO
# 1             1100015.0  Alta Floresta D'Oeste       11.0        RO
# 2             1100015.0  Alta Floresta D'Oeste       11.0        RO
# 3             1100023.0              Ariquemes       11.0        RO
# 4             1100023.0              Ariquemes       11.0        RO
# ...                 ...                    ...        ...       ...
# 16587         5222302.0          Vila Propício       52.0        GO
# 16588         5222302.0          Vila Propício       52.0        GO
# 16589         5300108.0               Brasília       53.0        DF
# 16590         5300108.0               Brasília       53.0        DF
# 16591         5300108.0               Brasília       53.0        DF
#
#        NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_REDACAO   IDHM  \
# ...

# %%
MediaEnemIDHM.head()
# Out:
#    CO_MUNICIPIO_ESC       NO_MUNICIPIO_ESC  CO_UF_ESC SG_UF_ESC  NU_NOTA_LC  \
# 0         1100015.0  Alta Floresta D'Oeste       11.0        RO  513.200000
# 1         1100015.0  Alta Floresta D'Oeste       11.0        RO  513.200000
# 2         1100015.0  Alta Floresta D'Oeste       11.0        RO  513.200000
# 3         1100023.0              Ariquemes       11.0        RO  517.528369
# 4         1100023.0              Ariquemes       11.0        RO  517.528369
#
#    NU_NOTA_MT  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_REDACAO   IDHM  IDHM_E  IDHM_L  \
# 0  506.317188  488.157812  495.502941       590.882353  0.329   0.112   0.617
# 1  506.317188  488.157812  495.502941       590.882353  0.483   0.262   0.698
# 2  506.317188  488.157812  495.502941       590.882353  0.641   0.526   0.763
# 3  515.933591  491.511969  503.362411       555.319149  0.432   0.199   0.684
# 4  515.933591  491.511969  503.362411       555.319149  0.556   0.343   0.742
#
#    IDHM_R
# 0   0.516
# 1   0.617
# ...

# %%
MediaEnemIDHM.plot.scatter('NU_NOTA_REDACAO', 'IDHM', figsize=(10, 10))
# Out:
# <AxesSubplot:xlabel='NU_NOTA_REDACAO', ylabel='IDHM'>

# %%
MediaEnemIDHM.plot.scatter('NU_NOTA_MT', 'IDHM', figsize=(10, 10))
# Out:
# <AxesSubplot:xlabel='NU_NOTA_MT', ylabel='IDHM'>

# %%
MediaEnemIDHM.dtypes
# Out:
# CO_MUNICIPIO_ESC    float64
# NO_MUNICIPIO_ESC     object
# CO_UF_ESC           float64
# SG_UF_ESC            object
# NU_NOTA_LC          float64
# NU_NOTA_MT          float64
# NU_NOTA_CN          float64
# NU_NOTA_CH          float64
# NU_NOTA_REDACAO     float64
# IDHM                float64
# IDHM_E              float64
# IDHM_L              float64
# IDHM_R              float64
# dtype: object

# %%
mean_REDACAO= MediaEnemIDHM.NU_NOTA_REDACAO.mean()
mean_IDHM= MediaEnemIDHM.IDHM.mean()

# %%
mean_REDACAO
# Out:
# 535.316368163806

# %%
mean_IDHM
# Out:
# 0.5212447700006035

# %%
idhmMunicipio = MediaEnemIDHM.IDHM
notaMunicipio = MediaEnemIDHM.NU_NOTA_REDACAO

q1 = (idhmMunicipio < mean_IDHM) & (notaMunicipio < mean_REDACAO)
q2 = (idhmMunicipio > mean_IDHM) & (notaMunicipio < mean_REDACAO)
q3 = (idhmMunicipio > mean_IDHM) & (notaMunicipio > mean_REDACAO)
q4 = (idhmMunicipio < mean_IDHM) & (notaMunicipio > mean_REDACAO)

fig, ax = plt.subplots(2,2, figsize=(15,7), sharex='col', sharey='row')
plt.subplots_adjust(wspace=0, hspace=0)

minRedacao =MediaEnemIDHM.NU_NOTA_REDACAO.min()
maxRedacao =MediaEnemIDHM.NU_NOTA_REDACAO.max()
minIDHM =MediaEnemIDHM.IDHM.min()
maxIDHM =MediaEnemIDHM.IDHM.max()

MediaEnemIDHM1 = MediaEnemIDHM[q1]
MediaEnemIDHM1.plot.scatter('NU_NOTA_REDACAO', 'IDHM', s=6, ax = ax[1,0], xlim = (minRedacao, mean_REDACAO), ylim =(minIDHM, mean_IDHM))

MediaEnemIDHM2 = MediaEnemIDHM[q2]
MediaEnemIDHM2.plot.scatter('NU_NOTA_REDACAO', 'IDHM', s=6, ax = ax[0,0], xlim = (minRedacao, mean_REDACAO), ylim =(maxIDHM, mean_IDHM))

MediaEnemIDHM3 = MediaEnemIDHM[q3]
MediaEnemIDHM3.plot.scatter('NU_NOTA_REDACAO', 'IDHM', s=6, ax = ax[0,1], xlim = (maxRedacao, mean_REDACAO), ylim =(maxIDHM, mean_IDHM))

MediaEnemIDHM4 = MediaEnemIDHM[q4]
MediaEnemIDHM4.plot.scatter('NU_NOTA_REDACAO', 'IDHM', s=6, ax = ax[1,1], xlim = (maxRedacao, mean_REDACAO), ylim =(minIDHM, mean_IDHM))
# Out:
# <AxesSubplot:xlabel='NU_NOTA_REDACAO', ylabel='IDHM'>

# %%
#Importando dados

municipios = pd.read_csv("C:/Users/BlueShift/Desktop/brutos/municipios.csv")

# %%
municipios.head()
# Out:
#    codigo_ibge                 nome  latitude  longitude  capital  codigo_uf  \
# 0      5200050      Abadia de Goiás -16.75730   -49.4412        0         52
# 1      3100104  Abadia dos Dourados -18.48310   -47.3916        0         31
# 2      5200100            Abadiânia -16.19700   -48.7057        0         52
# 3      3100203               Abaeté -19.15510   -45.4444        0         31
# 4      1500107           Abaetetuba  -1.72183   -48.8788        0         15
#
#    siafi_id  ddd       fuso_horario
# 0      1050   62  America/Sao_Paulo
# 1      4001   34  America/Sao_Paulo
# 2      9201   62  America/Sao_Paulo
# 3      4003   37  America/Sao_Paulo
# 4       401   91  America/Sao_Paulo

# %%
enem_idhm_municipios = pd.merge(MediaEnemIDHM, municipios,
                                how= 'left', left_on=['CO_MUNICIPIO_ESC'],
                            right_on=['codigo_ibge'])

# %%
enem_idhm_municipios.head()
# Out:
#    CO_MUNICIPIO_ESC       NO_MUNICIPIO_ESC  CO_UF_ESC SG_UF_ESC  NU_NOTA_LC  \
# 0         1100015.0  Alta Floresta D'Oeste       11.0        RO  513.200000
# 1         1100015.0  Alta Floresta D'Oeste       11.0        RO  513.200000
# 2         1100015.0  Alta Floresta D'Oeste       11.0        RO  513.200000
# 3         1100023.0              Ariquemes       11.0        RO  517.528369
# 4         1100023.0              Ariquemes       11.0        RO  517.528369
#
#    NU_NOTA_MT  NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_REDACAO   IDHM  ...  IDHM_R  \
# 0  506.317188  488.157812  495.502941       590.882353  0.329  ...   0.516
# 1  506.317188  488.157812  495.502941       590.882353  0.483  ...   0.617
# 2  506.317188  488.157812  495.502941       590.882353  0.641  ...   0.657
# 3  515.933591  491.511969  503.362411       555.319149  0.432  ...   0.593
# 4  515.933591  491.511969  503.362411       555.319149  0.556  ...   0.674
#
# ...

# %%
enem_idhm_municipios.plot.scatter(y='latitude', x='longitude', figsize= (10, 8))
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
enem_idhm_municipios.plot.scatter(y='latitude', x='longitude',
                                c= enem_idhm_municipios['NU_NOTA_REDACAO'],
                                cmap= 'RdYlGn',
                                 figsize= (12, 8), title= 'NU_NOTA_REDACAO')
# Out:
# <AxesSubplot:title={'center':'NU_NOTA_REDACAO'}, xlabel='longitude', ylabel='latitude'>

# %%
#Criando Subplots

fig, ax = plt.subplots(2,2, figsize=(20, 16))

enem_idhm_municipios.plot.scatter(y='latitude', x='longitude',
                                c= enem_idhm_municipios['NU_NOTA_CN'],
                                cmap= 'RdYlGn',
                                  title= 'NU_NOTA_CN', ax=ax[0,0])

enem_idhm_municipios.plot.scatter(y='latitude', x='longitude',
                                c= enem_idhm_municipios['NU_NOTA_CH'],
                                cmap= 'RdYlGn',
                                  title= 'NU_NOTA_CH', ax=ax[0,1])

enem_idhm_municipios.plot.scatter(y='latitude', x='longitude',
                                c= enem_idhm_municipios['NU_NOTA_LC'],
                                cmap= 'RdYlGn',
                                 title= 'NU_NOTA_LC', ax=ax[1,0])

enem_idhm_municipios.plot.scatter(y='latitude', x='longitude',
                                c= enem_idhm_municipios['NU_NOTA_MT'],
                                cmap= 'RdYlGn',
                                  title= 'NU_NOTA_MT', ax=ax[1,1])
# Out:
# <AxesSubplot:title={'center':'NU_NOTA_MT'}, xlabel='longitude', ylabel='latitude'>

# %%
#Criando Subplots IDHM

fig, ax = plt.subplots(2,2, figsize=(20, 16))

enem_idhm_municipios.plot.scatter(y='latitude', x='longitude',
                                c= enem_idhm_municipios['IDHM'],
                                cmap= 'coolwarm',
                                title= 'IDHM', ax=ax[0,0])

enem_idhm_municipios.plot.scatter(y='latitude', x='longitude',
                                c= enem_idhm_municipios['IDHM_E'],
                                cmap= 'coolwarm',
                                title= 'IDHM_E', ax=ax[0,1])

enem_idhm_municipios.plot.scatter(y='latitude', x='longitude',
                                c= enem_idhm_municipios['IDHM_R'],
                                cmap= 'coolwarm',
                                title= 'IDHM_R', ax=ax[1,0])

enem_idhm_municipios.plot.scatter(y='latitude', x='longitude',
                                c= enem_idhm_municipios['IDHM_L'],
                                cmap= 'coolwarm',
                                title= 'IDHM_L', ax=ax[1,1])
# Out:
# <AxesSubplot:title={'center':'IDHM_L'}, xlabel='longitude', ylabel='latitude'>
