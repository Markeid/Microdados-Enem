# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import re

# %%
microdadosEnem = pd.read_csv("C:/Users/BlueShift/Desktop/brutos/microdados_enem_2020/DADOS/MICRODADOS_ENEM_2020.csv", sep=";", encoding='ISO-8859-1')

# %%
microdadosEnem.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  200006271946    2020               11       F                1
# 1  200001195856    2020               11       M                2
# 2  200001943954    2020                4       F                2
# 3  200001908998    2020                2       M                1
# 4  200001634757    2020                4       F                1
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            2                 1                1               11          1
# 1            3                 1                1               11          1
# 2            3                 2                2                0          2
# 3            3                 1                2                0          2
# 4            3                 2                1                1          1
#
#    ...  Q016  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  Q025
# ...

# %%
microdadosEnem
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0        200006271946    2020               11       F                1
# 1        200001195856    2020               11       M                2
# 2        200001943954    2020                4       F                2
# 3        200001908998    2020                2       M                1
# 4        200001634757    2020                4       F                1
# ...               ...     ...              ...     ...              ...
# 5783104  200003396891    2020                2       F                1
# 5783105  200006040822    2020                3       M                1
# 5783106  200004928656    2020                3       F                1
# 5783107  200006774808    2020                4       F                1
# 5783108  200007078230    2020                2       F                1
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# ...

# %%
microdadosEnem.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
#        'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
#        'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
#        'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
#        'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
#        'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
#        'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
#        'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
#        'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
#        'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
# ...

# %%
colunasSelecionadas = ['NU_INSCRICAO', 'NU_NOTA_MT', 'NU_NOTA_REDACAO', 'Q001', 'Q002']

# %%
microdadosEnemSelecionado = microdadosEnem.filter(items=colunasSelecionadas)

# %%
microdadosEnemSelecionado
# Out:
#          NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002
# 0        200006271946         NaN              NaN  NaN  NaN
# 1        200001195856       711.3            580.0  NaN  NaN
# 2        200001943954         NaN              NaN    B    C
# 3        200001908998       759.4            760.0  NaN  NaN
# 4        200001634757         NaN              NaN    B    G
# ...               ...         ...              ...  ...  ...
# 5783104  200003396891       725.7            900.0    E    G
# 5783105  200006040822       719.5            660.0  NaN  NaN
# 5783106  200004928656       648.1            660.0  NaN  NaN
# 5783107  200006774808         NaN              NaN    G    G
# 5783108  200007078230       481.7            380.0    F    D
#
# [5783109 rows x 5 columns]

# %%
microdadosEnemSelecionado = microdadosEnemSelecionado.dropna()

# %%
microdadosEnemSelecionado
# Out:
#          NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002
# 5        200003132410       526.7            700.0    C    B
# 8        200006762554       448.5            600.0    B    C
# 11       200006138472       546.5            640.0    B    C
# 18       200003343448       420.3            800.0    C    C
# 19       200005966328       405.6            500.0    C    D
# ...               ...         ...              ...  ...  ...
# 5783084  200006585396       411.4            340.0    B    D
# 5783095  200002970643       332.7            440.0    A    B
# 5783101  200002621781       340.0            500.0    D    D
# 5783104  200003396891       725.7            900.0    E    G
# 5783108  200007078230       481.7            380.0    F    D
#
# [2561304 rows x 5 columns]

# %%
microdadosEnemSelecionado.head()
# Out:
#     NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002
# 5   200003132410       526.7            700.0    C    B
# 8   200006762554       448.5            600.0    B    C
# 11  200006138472       546.5            640.0    B    C
# 18  200003343448       420.3            800.0    C    C
# 19  200005966328       405.6            500.0    C    D

# %% [markdown]
# # 1 - Definir o Dicionário

# %%
#definir dicionário

q001e002Dicionario = {'A' : 'Nunca estudou.',
'B' : 'Não completou a 4ª série/5º ano do Ensino Fundamental.',
'C' : 'Completou a 4ª série/5º ano, mas não completou a 8ª série/9º ano do Ensino Fundamental.',
'D' : 'Completou a 8ª série/9º ano do Ensino Fundamental, mas não completou o Ensino Médio.',
'E' : 'Completou o Ensino Médio, mas não completou a Faculdade.',
'F' : 'Completou a Faculdade, mas não completou a Pós-graduação.',
'G' : 'Completou a Pós-graduação.',
'H' : 'Não sei.'}

# %%
microdadosEnemSelecionado.filter(items=['Q001', 'NU_INSCRICAO']).groupby('Q001').count()
# Out:
#       NU_INSCRICAO
# Q001
# A           113786
# B           483323
# C           352976
# D           284175
# E           736397
# F           233881
# G           157039
# H           199727

# %% [markdown]
# # 2 - Criação de Novas Colunas no DataFrame

# %%
#Inserindo coluna NO_Q001
microdadosEnemSelecionado['NO_Q001'] = [q001e002Dicionario[resp] for resp in microdadosEnemSelecionado.Q001]
# Out:
# <ipython-input-15-40edef3299b8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   microdadosEnemSelecionado['NO_Q001'] = [q001e002Dicionario[resp] for resp in microdadosEnemSelecionado.Q001]

# %%
#Inserindo coluna NO_Q002
microdadosEnemSelecionado['NO_Q002'] = [q001e002Dicionario[resp] for resp in microdadosEnemSelecionado.Q002]
# Out:
# <ipython-input-16-86adb9b23daa>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   microdadosEnemSelecionado['NO_Q002'] = [q001e002Dicionario[resp] for resp in microdadosEnemSelecionado.Q002]

# %%
microdadosEnemSelecionado.head()
# Out:
#     NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002  \
# 5   200003132410       526.7            700.0    C    B
# 8   200006762554       448.5            600.0    B    C
# 11  200006138472       546.5            640.0    B    C
# 18  200003343448       420.3            800.0    C    C
# 19  200005966328       405.6            500.0    C    D
#
#                                               NO_Q001  \
# 5   Completou a 4ª série/5º ano, mas não completou...
# 8   Não completou a 4ª série/5º ano do Ensino Fund...
# 11  Não completou a 4ª série/5º ano do Ensino Fund...
# 18  Completou a 4ª série/5º ano, mas não completou...
# 19  Completou a 4ª série/5º ano, mas não completou...
#
#                                               NO_Q002
# 5   Não completou a 4ª série/5º ano do Ensino Fund...
# 8   Completou a 4ª série/5º ano, mas não completou...
# 11  Completou a 4ª série/5º ano, mas não completou...
# 18  Completou a 4ª série/5º ano, mas não completou...
# ...

# %% [markdown]
# # 3 - Comparação de dados de escolaridade entre Pai x Mãe, no conjunto;
#
# # Utilizando DataFrame .filter(), .groupby(), .count() e .sort_values()

# %%
#1 - Distribuição de candidatos por escolaridade do Pai:

microdadosEnemSelecionado.filter(items=['NU_INSCRICAO', 'NO_Q001']).groupby('NO_Q001').count().sort_values(by='NU_INSCRICAO', ascending=False)
# Out:
#                                                     NU_INSCRICAO
# NO_Q001
# Completou o Ensino Médio, mas não completou a F...        736397
# Não completou a 4ª série/5º ano do Ensino Funda...        483323
# Completou a 4ª série/5º ano, mas não completou ...        352976
# Completou a 8ª série/9º ano do Ensino Fundament...        284175
# Completou a Faculdade, mas não completou a Pós-...        233881
# Não sei.                                                  199727
# Completou a Pós-graduação.                                157039
# Nunca estudou.                                            113786

# %%
#2  - Distribuição de candidatos por escolaridade da Mãe:

microdadosEnemSelecionado.filter(items=['NU_INSCRICAO', 'NO_Q002']).groupby('NO_Q002').count().sort_values(by='NU_INSCRICAO', ascending=False)
# Out:
#                                                     NU_INSCRICAO
# NO_Q002
# Completou o Ensino Médio, mas não completou a F...        881498
# Não completou a 4ª série/5º ano do Ensino Funda...        358276
# Completou a Faculdade, mas não completou a Pós-...        312436
# Completou a 4ª série/5º ano, mas não completou ...        306430
# Completou a 8ª série/9º ano do Ensino Fundament...        294949
# Completou a Pós-graduação.                                275108
# Nunca estudou.                                             76337
# Não sei.                                                   56270

# %% [markdown]
# # 4 - Desempenho em Matemática segundo a escolaridade Pai x Mãe

# %%
#por escolaridade do Pai:

microdadosEnemSelecionado.filter(items=['NU_NOTA_MT', 'NO_Q001']).groupby('NO_Q001').mean().sort_values(by='NU_NOTA_MT', ascending=False)
# Out:
#                                                     NU_NOTA_MT
# NO_Q001
# Completou a Pós-graduação.                          620.382538
# Completou a Faculdade, mas não completou a Pós-...  598.426301
# Completou o Ensino Médio, mas não completou a F...  534.797631
# Completou a 8ª série/9º ano do Ensino Fundament...  511.877629
# Completou a 4ª série/5º ano, mas não completou ...  499.029500
# Não sei.                                            490.961933
# Não completou a 4ª série/5º ano do Ensino Funda...  478.183048
# Nunca estudou.                                      455.340086

# %%
#por escolaridade da Mãe:

microdadosEnemSelecionado.filter(items=['NU_NOTA_MT', 'NO_Q002']).groupby('NO_Q002').mean().sort_values(by='NU_NOTA_MT', ascending=False)
# Out:
#                                                     NU_NOTA_MT
# NO_Q002
# Completou a Pós-graduação.                          594.897645
# Completou a Faculdade, mas não completou a Pós-...  580.438367
# Completou o Ensino Médio, mas não completou a F...  523.880757
# Completou a 8ª série/9º ano do Ensino Fundament...  499.628369
# Completou a 4ª série/5º ano, mas não completou ...  488.812625
# Não sei.                                            478.135403
# Não completou a 4ª série/5º ano do Ensino Funda...  470.848168
# Nunca estudou.                                      448.565889

# %%
microdadosEnemSelecionado['SG_UF_ESC'] = microdadosEnem.SG_UF_ESC
# Out:
# <ipython-input-22-10131b7cb646>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   microdadosEnemSelecionado['SG_UF_ESC'] = microdadosEnem.SG_UF_ESC

# %%
microdadosEnemSelecionado = microdadosEnemSelecionado.dropna()

# %%
microdadosEnemSelecionado
# Out:
#          NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002  \
# 36       200003209996       433.9            620.0    E    E
# 65       200003350911       384.2            880.0    A    C
# 84       200005725669       404.6            600.0    C    E
# 89       200004462096       669.8            820.0    B    C
# 93       200002727241       743.0            920.0    E    E
# ...               ...         ...              ...  ...  ...
# 5783066  200003534563       429.4            620.0    E    E
# 5783084  200006585396       411.4            340.0    B    D
# 5783101  200002621781       340.0            500.0    D    D
# 5783104  200003396891       725.7            900.0    E    G
# 5783108  200007078230       481.7            380.0    F    D
#
#                                                    NO_Q001  \
# 36       Completou o Ensino Médio, mas não completou a ...
# 65                                          Nunca estudou.
# ...

# %%
microdadosEnemSelecionado.head()
# Out:
#     NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002  \
# 36  200003209996       433.9            620.0    E    E
# 65  200003350911       384.2            880.0    A    C
# 84  200005725669       404.6            600.0    C    E
# 89  200004462096       669.8            820.0    B    C
# 93  200002727241       743.0            920.0    E    E
#
#                                               NO_Q001  \
# 36  Completou o Ensino Médio, mas não completou a ...
# 65                                     Nunca estudou.
# 84  Completou a 4ª série/5º ano, mas não completou...
# 89  Não completou a 4ª série/5º ano do Ensino Fund...
# 93  Completou o Ensino Médio, mas não completou a ...
#
#                                               NO_Q002 SG_UF_ESC
# 36  Completou o Ensino Médio, mas não completou a ...        AM
# 65  Completou a 4ª série/5º ano, mas não completou...        PI
# 84  Completou o Ensino Médio, mas não completou a ...        MT
# ...

# %%
microdadosEnemSelecionado.filter(items=['NU_NOTA_REDACAO', 'NO_Q002'])\
                        .groupby('NO_Q002')\
                        .mean().sort_values(by='NU_NOTA_REDACAO', ascending=False)
# Out:
#                                                     NU_NOTA_REDACAO
# NO_Q002
# Completou a Pós-graduação.                               703.645277
# Completou a Faculdade, mas não completou a Pós-...       679.745940
# Completou o Ensino Médio, mas não completou a F...       609.437322
# Completou a 8ª série/9º ano do Ensino Fundament...       567.123746
# Completou a 4ª série/5º ano, mas não completou ...       547.964557
# Não completou a 4ª série/5º ano do Ensino Funda...       515.430502
# Não sei.                                                 514.565493
# Nunca estudou.                                           474.972790

# %%
microdadosEnemSelecionado.filter(items=['NU_NOTA_REDACAO', 'NO_Q002'])\
                        .where(microdadosEnemSelecionado.SG_UF_ESC == 'SP')\
                        .groupby('NO_Q002')\
                        .mean().sort_values(by='NU_NOTA_REDACAO', ascending=False)
# Out:
#                                                     NU_NOTA_REDACAO
# NO_Q002
# Completou a Pós-graduação.                               682.406866
# Completou a Faculdade, mas não completou a Pós-...       664.238143
# Completou o Ensino Médio, mas não completou a F...       605.642481
# Completou a 8ª série/9º ano do Ensino Fundament...       576.942993
# Completou a 4ª série/5º ano, mas não completou ...       570.986239
# Não completou a 4ª série/5º ano do Ensino Funda...       546.751781
# Não sei.                                                 542.446483
# Nunca estudou.                                           493.243243

# %%
microdadosEnemSelecionado.filter(items=['SG_UF_ESC','NU_NOTA_REDACAO', 'NO_Q002'])\
                        .groupby(['SG_UF_ESC', 'NO_Q002'])\
                        .mean()
# Out:
#                                                               NU_NOTA_REDACAO
# SG_UF_ESC NO_Q002
# AC        Completou a 4ª série/5º ano, mas não completou ...       521.871921
#           Completou a 8ª série/9º ano do Ensino Fundament...       542.767857
#           Completou a Faculdade, mas não completou a Pós-...       624.189526
#           Completou a Pós-graduação.                               654.095745
#           Completou o Ensino Médio, mas não completou a F...       556.282723
# ...                                                                       ...
# TO        Completou a Pós-graduação.                               655.590327
#           Completou o Ensino Médio, mas não completou a F...       561.460751
#           Nunca estudou.                                           377.254902
#           Não completou a 4ª série/5º ano do Ensino Funda...       464.587814
#           Não sei.                                                 516.382979
#
# ...

# %%
fig, ax = plt.subplots(figsize=(16, 8))
plt.suptitle('Nota da Redação x Escolaridade x Estado')

microdadosEnemSelecionado.filter(items=['SG_UF_ESC','NU_NOTA_REDACAO', 'Q002'])\
                        .where(microdadosEnemSelecionado.Q002 != 'H')\
                        .groupby(['SG_UF_ESC', 'Q002'])\
                        .mean().sort_values(by='NU_NOTA_REDACAO', ascending=False)\
                        .unstack().plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='SG_UF_ESC'>

# %%
#fig, ax = plt.subplots(figsize=(16, 8))
#plt.suptitle('Nota da Redação x Escolaridade x Estado')

ax = microdadosEnemSelecionado.filter(items=['SG_UF_ESC','NU_NOTA_REDACAO', 'Q002'])\
                        .where(microdadosEnemSelecionado.Q002 != 'H')\
                        .groupby(['SG_UF_ESC', 'Q002'])\
                        .mean().sort_values(by='NU_NOTA_REDACAO', ascending=False)\
                        .unstack().plot(figsize=(16,8), colormap= 'viridis')

ax.set_title('Nota da Redação x Escolaridade x Estado', fontsize= 20)
#ax.legend(bbox_to_anchor=(1.05,1), loc=0, borderaxespad=0.)

handles, labels = ax.get_legend_handles_labels()
#print(labels)

edited_labels = [re.search(',\s(.+?)\)', label).group(1) for label in labels]
ax.legend(bbox_to_anchor=(1.05,1), loc=0, borderaxespad=0.)

textedictQ002 = ""
for a, b in q001e002Dicionario.items():
    textedictQ002 = textedictQ002 + "{key} : {value}\n".format(key=a, value=b)

ax.text(0, 1, textedictQ002, transform= ax.transAxes, fontsize= 10, bbox={'boxstyle':'round', 'facecolor':'wheat', 'alpha': 0.2})
# Out:
# Text(0, 1, 'A : Nunca estudou.\nB : Não completou a 4ª série/5º ano do Ensino Fundamental.\nC : Completou a 4ª série/5º ano, mas não completou a 8ª série/9º ano do Ensino Fundamental.\nD : Completou a 8ª série/9º ano do Ensino Fundamental, mas não completou o Ensino Médio.\nE : Completou o Ensino Médio, mas não completou a Faculdade.\nF : Completou a Faculdade, mas não completou a Pós-graduação.\nG : Completou a Pós-graduação.\nH : Não sei.\n')
