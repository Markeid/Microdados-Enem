# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1, 2, 3, 4])
plt.show()

# %%
plt.plot([1, 2, 3, 4], "ro")
plt.show()

# %%
x = np.arange(0, 10, 0.1)
fig1, f1_axes = plt.subplots(ncols=2, nrows=2, figsize=(15, 10))
fig1.suptitle("Titúlo Maior", size= 30)

f1_axes[0,0].plot(np.sin(x), label="sen(x)")
f1_axes[0,0].plot(np.cos(x), label="cos(x)")
f1_axes[0,0].set_title("Caixa 1")
f1_axes[0,0].set_xlabel("Caixa 1 - Label X")
f1_axes[0,0].set_ylabel("Caixa 1 - Label Y")
f1_axes[0,0].legend()

f1_axes[0,1].plot(np.cos(x))
f1_axes[0,1].set_title("Caixa 2")

f1_axes[1,0].plot(np.tan(x))
f1_axes[1,0].set_title("Caixa 3")

f1_axes[1,1].set_title("Caixa 4")
# Out:
# Text(0.5, 1.0, 'Caixa 4')

# %%
f1_axes
# Out:
# array([[<AxesSubplot:title={'center':'Caixa 1'}, xlabel='Caixa 1 - Label X', ylabel='Caixa 1 - Label Y'>,
#         <AxesSubplot:title={'center':'Caixa 2'}>],
#        [<AxesSubplot:title={'center':'Caixa 3'}>,
#         <AxesSubplot:title={'center':'Caixa 4'}>]], dtype=object)
